# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ####                    READING DATA              #####

# %% [markdown]
# ####            DATASET-1         #####

# %%
df1 = pd.read_excel('dataset_1.xlsx')

# %%
df1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %% [markdown]
# ####               DATA EXPLORATION            ####

# %%
df1.head(10)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
# 5        6 2011-01-01       1   0     1   5    False        6           2
# 6        7 2011-01-01       1   0     1   6    False        6           1
# 7        8 2011-01-01       1   0     1   7    False        6           1
# 8        9 2011-01-01       1   0     1   8    False        6           1
# 9       10 2011-01-01       1   0     1   9    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24
# 5  0.24
# 6  0.22
# 7  0.20
# 8  0.24
# 9  0.32

# %%
df1.tail(10)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 600      601 2011-01-28       1   0     1   6    False        5           2
# 601      602 2011-01-28       1   0     1   7    False        5           2
# 602      603 2011-01-28       1   0     1   8    False        5           2
# 603      604 2011-01-28       1   0     1   9    False        5           3
# 604      605 2011-01-28       1   0     1  10    False        5           3
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 600  0.18
# 601  0.16
# 602  0.16
# 603  0.18
# 604  0.18
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
df1.shape
# Out:
# (610, 10)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
df1['weathersit'] = df1['weathersit'].astype('category')
df1['season'] = df1['season'].astype('int')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int32
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    category
#  9   temp        610 non-null    float64
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int32(1), int64(5)
# memory usage: 37.3 KB

# %% [markdown]
# ####    FILTERING DATA   #####

# %%
df1.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %% [markdown]
# ####      DATA MANIPULATION       ####

# %%
df1.drop('yr', axis=1, inplace= True)
df1.drop('mnth', axis=1, inplace= True)

# %%
df1
# Out:
#      instant     dteday  season  hr  holiday  weekday weathersit  temp
# 0          1 2011-01-01       1   0    False        6          1  0.24
# 1          2 2011-01-01       1   1    False        6          1  0.22
# 2          3 2011-01-01       1   2    False        6          1  0.22
# 3          4 2011-01-01       1   3    False        6          1  0.24
# 4          5 2011-01-01       1   4    False        6          1  0.24
# ..       ...        ...     ...  ..      ...      ...        ...   ...
# 605      606 2011-01-28       1  11    False        5          3  0.18
# 606      607 2011-01-28       1  12    False        5          3  0.18
# 607      608 2011-01-28       1  13    False        5          3  0.18
# 608      609 2011-01-28       1  14    False        5          3  0.22
# 609      610 2011-01-28       1  15    False        5          2  0.20
#
# [610 rows x 8 columns]

# %%
def fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius

df1['temp'] = df1['temp'].apply(fahrenheit_to_celsius)

# %%
df1
# Out:
#      instant     dteday  season  hr  holiday  weekday weathersit       temp
# 0          1 2011-01-01       1   0    False        6          1 -17.644444
# 1          2 2011-01-01       1   1    False        6          1 -17.655556
# 2          3 2011-01-01       1   2    False        6          1 -17.655556
# 3          4 2011-01-01       1   3    False        6          1 -17.644444
# 4          5 2011-01-01       1   4    False        6          1 -17.644444
# ..       ...        ...     ...  ..      ...      ...        ...        ...
# 605      606 2011-01-28       1  11    False        5          3 -17.677778
# 606      607 2011-01-28       1  12    False        5          3 -17.677778
# 607      608 2011-01-28       1  13    False        5          3 -17.677778
# 608      609 2011-01-28       1  14    False        5          3 -17.655556
# 609      610 2011-01-28       1  15    False        5          2 -17.666667
#
# [610 rows x 8 columns]

# %%
df1.describe()
# Out:
#           instant                         dteday  season          hr  \
# count  610.000000                            610   610.0  610.000000
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0   11.795082
# min      1.000000            2011-01-01 00:00:00     1.0    0.000000
# 25%    153.250000            2011-01-07 00:00:00     1.0    6.000000
# 50%    305.500000            2011-01-14 00:00:00     1.0   12.000000
# 75%    457.750000            2011-01-21 00:00:00     1.0   18.000000
# max    610.000000            2011-01-28 00:00:00     1.0   23.000000
# std    176.236111                            NaN     0.0    6.852107
#
#           weekday        temp
# count  610.000000  610.000000
# mean     2.977049  -17.668397
# min      0.000000  -17.766667
# 25%      1.000000  -17.688889
# 50%      3.000000  -17.666667
# 75%      5.000000  -17.647222
# max      6.000000  -17.522222
# std      2.054943    0.045169

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###    VISUALIZATION's

# %% [markdown]
# #  strip plot

# %%
# List of categorical columns to plot against `temp`
categorical_columns = ['season', 'weekday', 'weathersit', 'holiday']

# Set up the plot grid (adjust rows and columns as needed)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Loop over the categorical columns and create strip plots
for i, col in enumerate(categorical_columns):
    ax = axes[i // 2, i % 2]  # Determine the subplot location
    sns.stripplot(x=col, y='temp', data=df1, jitter=True, palette="Set2", ax=ax)
    ax.set_title(f'Strip Plot: Temperature vs {col.capitalize()}')
    ax.set_xlabel(col.capitalize())
    ax.set_ylabel('Temperature (Celsius)')

plt.tight_layout()
plt.show()

# %%
# This will create a set of strip plots for each of the categorical columns and show how the temperature varies across those categories.

# %% [markdown]
# # ECDF PLOT

# %%
# List of categorical columns to plot ECDF for `temp`
categorical_columns = ['season', 'weekday', 'weathersit', 'holiday']

# Set up the plot grid (adjust rows and columns as needed)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Loop over the categorical columns and create ECDF plots
for i, col in enumerate(categorical_columns):
    ax = axes[i // 2, i % 2]  # Determine the subplot location
    sns.ecdfplot(data=df1, x='temp', hue=col, ax=ax, palette="Set2", legend=True)
    ax.set_title(f'ECDF Plot: Temperature vs {col.capitalize()}')
    ax.set_xlabel('Temperature (Celsius)')
    ax.set_ylabel('ECDF')

plt.tight_layout()
plt.show()

# %%
#This will generate a set of ECDF plots showing the cumulative distribution of temperature for each category of the selected categorical columns. The ECDF curve will show the proportion of temperature values less than or equal to the corresponding temperature value along the x-axis.

# %% [markdown]
# #  HISATOGRAM PLOT

# %%
numeric_columns = [ 'hr', 'holiday', 'weekday', 'weathersit', 'temp']

# Set up the plot grid
plt.figure(figsize=(12, 8))

# Iterate over numeric columns and plot histograms for each
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df1[col], bins=20, kde=True, color='skyblue', edgecolor='black')
    plt.title(f'Histogram for {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
# Skewness in a plot indicates the asymmetry of the distribution, with right skew showing a longer tail on the right and left skew showing a longer tail on the left. Clusters represent groups of closely packed data points, highlighting ranges with higher frequency or concentration of values.

# %% [markdown]
# #   SCATTER PLOT

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df1, x='temp', y='dteday', hue='season', palette='dark')
plt.title('Weather Situation vs. date:')
plt.xlabel('weather')
plt.ylabel('date')
plt.legend(title='weather')
plt.show()

# %%
# A scatter plot shows the relationship between two numerical variables by displaying individual data points as dots on a two-dimensional grid. The pattern of dots helps identify correlations, trends, and potential outliers in the data.

# %% [markdown]
# #   LINE PLOT

# %%
sns.lineplot(x='hr', y='temp', data=df1)
plt.title('Temperature over time')
plt.xlabel('time')
plt.ylabel('Temperature')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x='dteday', y='temp', data=df1)
plt.title('Temperature Over date')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45)
plt.show()

# %%
# A line plot displays data points connected by a line, showing trends or changes over time or across a continuous variable. It helps visualize the progression, fluctuations, and patterns in the data.

# %% [markdown]
# #  BAR PLOTS

# %%
data = {
    'dteday': pd.date_range(start='2011-01-01', periods=610, freq='H'),
    'season': [1]*610,
    'hr': [i%24 for i in range(610)],
    'holiday': [0, 1]*305,
    'weekday': [i%7 for i in range(610)],
    'weathersit': [1]*610,
    'temp': [-17.644444 + (i%3) * 0.01 for i in range(610)]
}

df = pd.DataFrame(data)

# Create a 3-row layout for the bar plots
fig, axes = plt.subplots(3, 2, figsize=(14, 12))

# 1st Row: Bar Plot for 'season' and 'hr' (Hour)
sns.countplot(x='season', data=df1, palette='viridis', ax=axes[0, 0])
axes[0, 0].set_title('Bar Plot for Season')
axes[0, 0].set_xlabel('Season')
axes[0, 0].set_ylabel('Count')

sns.countplot(x='hr', data=df1, palette='coolwarm', ax=axes[0, 1])
axes[0, 1].set_title('Bar Plot for Hour')
axes[0, 1].set_xlabel('Hour')
axes[0, 1].set_ylabel('Count')

# 2nd Row: Bar Plot for 'holiday' and 'weekday'
sns.countplot(x='holiday', data=df1, palette='Blues', ax=axes[1, 0])
axes[1, 0].set_title('Bar Plot for Holiday')
axes[1, 0].set_xlabel('Holiday (0 = No, 1 = Yes)')
axes[1, 0].set_ylabel('Count')

sns.countplot(x='weekday', data=df1, palette='Set2', ax=axes[1, 1])
axes[1, 1].set_title('Bar Plot for Weekday')
axes[1, 1].set_xlabel('Weekday')
axes[1, 1].set_ylabel('Count')

# 3rd Row: Bar Plot for 'weathersit' and 'temp' (Average Temperature by Hour)
sns.countplot(x='weathersit', data=df1, palette='Spectral', ax=axes[2, 0])
axes[2, 0].set_title('Bar Plot for Weather Situation')
axes[2, 0].set_xlabel('Weather Situation')
axes[2, 0].set_ylabel('Count')

sns.barplot(x='hr', y='temp', data=df1, palette='YlOrRd', ax=axes[2, 1])
axes[2, 1].set_title('Average Temperature by Hour')
axes[2, 1].set_xlabel('Hour')
axes[2, 1].set_ylabel('Average Temperature')

# Adjust layout for better visibility
plt.tight_layout()
plt.show()

# %%
# A bar plot uses rectangular bars to represent the frequency or value of categories, with the length of each bar corresponding to the data value. It is effective for comparing discrete categories or groups.

# %% [markdown]
# #  PIE CHART

# %%
data = {
    'dteday': pd.date_range(start='2011-01-01', periods=610, freq='H'),
    'season': [1]*610,
    'hr': [i%24 for i in range(610)],
    'holiday': [0, 1]*305,
    'weekday': [i%7 for i in range(610)],
    'weathersit': [1]*610,
    'temp': [-17.644444 + (i%3) * 0.01 for i in range(610)]
}

df = pd.DataFrame(data)

# Create a 2-row layout for pie charts
fig, axes = plt.subplots(2, 3, figsize=(16, 12))  # 2 rows, 3 columns

# Pie Chart for 'season' (distribution of seasons)
season_counts = df1['season'].value_counts()
axes[0, 0].pie(season_counts, labels=season_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
axes[0, 0].set_title('Season Distribution')

# Pie Chart for 'holiday' (Holiday vs. Non-Holiday)
holiday_counts = df1['holiday'].value_counts()
axes[0, 1].pie(holiday_counts, labels=holiday_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff6347', '#90ee90'])
axes[0, 1].set_title('Holiday Distribution')

# Pie Chart for 'weekday' (distribution of weekdays)
weekday_counts = df1['weekday'].value_counts()
axes[0, 2].pie(weekday_counts, labels=weekday_counts.index, autopct='%1.1f%%', startangle=90, colors=['#f3b6d1', '#c9c1ff', '#d0f0f5', '#ffccff', '#ffb3e6', '#e0b3ff', '#d9d9d9'])
axes[0, 2].set_title('Weekday Distribution')

# Pie Chart for 'weathersit' (distribution of weather situations)
weathersit_counts = df1['weathersit'].value_counts()
axes[1, 0].pie(weathersit_counts, labels=weathersit_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ffcccb', '#d3d3d3', '#add8e6'])
axes[1, 0].set_title('Weather Situation Distribution')

# Pie Chart for 'hr' (Top 12 hours distribution for visualization clarity)
hour_counts = df1['hr'].value_counts().head(12)
axes[1, 1].pie(hour_counts, labels=hour_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
axes[1, 1].set_title('Hourly Distribution (Top 12 Hours)')

# Placeholder empty chart for the last position
axes[1, 2].axis('off')  # No plot in this position
axes[1, 2].set_title('')  # Blank title

# Adjust layout for better visibility
plt.tight_layout()
plt.show()

# %%
# A pie chart is a circular graph divided into slices, where each slice represents a proportion of the whole. It is used to show the relative sizes of different categories as parts of a total.

# %% [markdown]
# #                    READING DATA              #####

# %% [markdown]
# ##            DATASET-2         #####

# %%
df2 = pd.read_excel('dataset_2.xlsx')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %% [markdown]
# ####               DATA EXPLORATION            ####

# %%
df2.head(10)
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81     0.0000       3          13   16
# 1           1        2  0.2727  0.80     0.0000       8          32   40
# 2           2        3  0.2727  0.80     0.0000       5          27   32
# 3           3        4  0.2879  0.75     0.0000       3          10   13
# 4           4        5  0.2879  0.75     0.0000       0           1    1
# 5           5        6  0.2576  0.75     0.0896       0           1    1
# 6           6        7  0.2727  0.80     0.0000       2           0    2
# 7           7        8  0.2576  0.86     0.0000       1           2    3
# 8           8        9     NaN  0.75     0.0000       1           7    8
# 9           9       10  0.3485  0.76     0.0000       8           6   14

# %%
df2.tail(10)
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 600         600      601  0.1970  0.80     0.1343       0          16   16
# 601         601      602  0.1970  0.86     0.0896       2          58   60
# 602         602      603  0.1970  0.86     0.0896       2         155  157
# 603         603      604  0.2121  0.86     0.0896       6          95  101
# 604         604      605  0.2121  0.86     0.1045       0          49   49
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
df2.shape
# Out:
# (610, 8)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %% [markdown]
# #   FILTERING DATA   #####

# %%
df2.isna().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Their are some missing values in 'atemp' so we will handle it by using some function.

# %%
df2['atemp'] = df2['atemp'].fillna(df2['atemp'].mean())
print(df2.isna().sum())
# Out:
# Unnamed: 0    0
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# #     DATA MANIPULATION       ####

# %%
df2.drop('Unnamed: 0', axis=1, inplace= True)

# %%
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
def fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius

df2['atemp'] = df2['atemp'].apply(fahrenheit_to_celsius)

# %%
df2
# Out:
#      instant      atemp   hum  windspeed  casual  registered  cnt
# 0          1 -17.617833  0.81     0.0000       3          13   16
# 1          2 -17.626278  0.80     0.0000       8          32   40
# 2          3 -17.626278  0.80     0.0000       5          27   32
# 3          4 -17.617833  0.75     0.0000       3          10   13
# 4          5 -17.617833  0.75     0.0000       0           1    1
# ..       ...        ...   ...        ...     ...         ...  ...
# 605      606 -17.659944  0.93     0.1045       0          30   30
# 606      607 -17.659944  0.93     0.1045       1          28   29
# 607      608 -17.659944  0.93     0.1045       0          31   31
# 608      609 -17.626278  0.80     0.0000       2          36   38
# 609      610 -17.634667  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
df2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000  -17.666703    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.043400    0.175440    0.121806    6.319945   47.021204
# min      1.000000  -17.777778    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000  -17.693611    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000  -17.668333    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000  -17.651500    0.690000    0.283600    6.000000   70.000000
# max    610.000000  -17.525278    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #    VISUALIZATION's

# %% [markdown]
# #  HISATOGRAM PLOT

# %%
# List of columns to plot histograms for
columns = ['atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# Create histograms for each column
plt.figure(figsize=(12, 10))

# Loop through the columns and create subplots
for i, column in enumerate(columns, 1):
    plt.subplot(2, 3, i)  # 2 rows, 3 columns of subplots
    sns.histplot(df2[column], kde=True, bins=20)  # `kde=True` adds a Kernel Density Estimate curve
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
# A histogram plot shows the frequency distribution of a continuous variable by dividing the data into bins and counting how many data points fall into each bin. It helps visualize the underlying distribution, whether it’s skewed, uniform, or normal, and the spread of the data.

# %% [markdown]
# #  LINE PLOT

# %%
# Line plot for windspeed vs cnt over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=df2, x='instant', y='windspeed', color='green', label='Windspeed')
sns.lineplot(data=df2, x='instant', y='cnt', color='blue', label='Count of Users')

# Adding titles and labels
plt.title("Windspeed vs Count of Users Over Time", fontsize=16)
plt.xlabel("Time (instant)", fontsize=12)
plt.ylabel("Count of Users (cnt) / Windspeed", fontsize=12)

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
#Trends in Windspeed and User Count: You might observe how changes in wind speed correspond with fluctuations in the number of users.
#Comparing Two Variables: By overlaying both windspeed and cnt, you can visually inspect how changes in one variable might influence the other over time.

# %% [markdown]
# #  STACK PLOT

# %%
# Extract the data for casual and registered users
casual_users = df2['casual']
registered_users = df2['registered']

# Create the stack plot
plt.figure(figsize=(10, 6))
plt.stackplot(df2['instant'], casual_users, registered_users, labels=['Casual Users', 'Registered Users'], alpha=0.6)

# Add titles and labels
plt.title("Stack Plot: Casual and Registered Users over Time", fontsize=14)
plt.xlabel("Time (Instant)", fontsize=12)
plt.ylabel("User Count", fontsize=12)

# Show the legend
plt.legend(loc='upper left')

# Display the plot
plt.show()

# %%
#The stack plot will help you visualize how the number of casual users and registered users changes over time or across records.

# %% [markdown]
# #  PIE CHART

# %%
data = {
    'instant': range(1, 611),
    'atemp': [-17.617833, -17.626278, -17.626278, -17.617833, -17.617833] * 122,
    'hum': [0.81, 0.80, 0.80, 0.75, 0.75] * 122,
    'windspeed': [0.0000, 0.0000, 0.0000, 0.0000, 0.0000] * 122,
    'casual': [3, 8, 5, 3, 0] * 122,
    'registered': [13, 32, 27, 10, 1] * 122,
    'cnt': [16, 40, 32, 13, 1] * 122,
}

# Create DataFrame
df = pd.DataFrame(data)

# Define a function to plot a pie chart for a given column
def plot_pie_chart(df2, column_name):
    # For numerical columns like casual, registered, and cnt, use value_counts
    data = df[column_name].value_counts()
    
    # Plot the pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90, colors=['#ffcc99', '#ff6666', '#ff3333'])
    plt.title(f'Pie Chart for {column_name.capitalize()}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
    plt.show()

# List of columns for which to create pie charts
columns = ['casual', 'registered', 'cnt']

# Plot pie charts for each column
for column in columns:
    plot_pie_chart(df2, column)

# %%
#The pie chart reveals the proportion of casual users versus registered users, highlighting the relative contribution of each group to the overall user activity.

# %% [markdown]
# #        MERGING DATA- 1,2

# %%
df1 = pd.read_excel('dataset_1.xlsx')

# %%
df = pd.merge(df1, df2, on='instant', how='inner')

# %%
df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #  VISUALIZATION's

# %% [markdown]
# # Bar Plot

# %%
# Set up the figure with a size to fit multiple plots
fig, axes = plt.subplots(2, 4, figsize=(20, 12))  # Adjust size if necessary
axes = axes.flatten()

# List of columns to create bar plots for
columns = ['holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual']

# Loop to create a bar plot for each column
for i, column in enumerate(columns):
    ax = axes[i]
    
    # For categorical columns, count the occurrences
    if df[column].dtype == 'object' or df[column].dtype == 'int64':  
        sns.countplot(x=column, data=df, ax=ax, palette='Set2')
    else:
        # For numerical columns, create a bar plot of the mean per category
        df[column].value_counts().plot(kind='bar', ax=ax, color='lightblue')
        
    ax.set_title(f'Bar Plot of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
#Holiday: Shows whether there is a higher user activity on holidays compared to non-holidays.
#Weekday: Reveals which days of the week see more user activity.
#Weather Situation: Indicates how different weather conditions affect user count.
#Temperature: Demonstrates the distribution of temperature values and their correlation with user activity.
#Apparent Temperature: Shows the distribution of apparent temperatures and their impact on user engagement.
#Humidity: Displays how varying humidity levels influence user activity.
#Windspeed: Reveals the relationship between wind speed and the number of users.
#Casual Users: Highlights the distribution of casual users across different records and time periods.

# %% [markdown]
# # Histogram Plot

# %%
# Set up the figure with a size to fit multiple plots
fig, axes = plt.subplots(2, 3, figsize=(20, 12))  # Adjust size if necessary
axes = axes.flatten()

# List of numerical columns for the histogram plots
numerical_columns = ['temp', 'atemp', 'hum', 'windspeed', 'casual']

# Loop to create a histogram for each numerical column
for i, column in enumerate(numerical_columns):
    ax = axes[i]
    sns.histplot(df[column], kde=True, ax=ax, color='lightblue', bins=30)  # KDE is optional
    ax.set_title(f'Histogram of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
#For temp, atemp, hum, and windspeed, the histograms will show if there are any skewed distributions or if data points are concentrated around certain values.
#The casual users histogram will indicate whether there are many records with low casual users or if there are outliers with a high number of casual users.

# %% [markdown]
# # STACK Plot

# %%
# Sample time-based data (assuming 'instant' as time and 'casual' and 'registered' as components)
time = df['instant']  # or use df['dteday'] for date-based plotting
casual_users = df['casual']
registered_users = df['registered']

# Stack plot
plt.figure(figsize=(12, 6))
plt.stackplot(time, casual_users, registered_users, labels=['Casual Users', 'Registered Users'], alpha=0.6)

plt.title('Stack Plot of Casual and Registered Users Over Time')
plt.xlabel('Time (Instant)')
plt.ylabel('User Count')
plt.legend(loc='upper left')

plt.show()

# %%
#The stack plot will show how the casual and registered users' contributions change over time.

# %% [markdown]
# # PIE CHART

# %%
# Generate pie charts for the categorical columns
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# Season pie chart
season_counts = df['season'].value_counts()
axes[0, 0].pie(season_counts, labels=season_counts.index, autopct='%1.1f%%', startangle=90)
axes[0, 0].set_title('Season')

# Holiday pie chart
holiday_counts = df['holiday'].value_counts()
axes[0, 1].pie(holiday_counts, labels=holiday_counts.index, autopct='%1.1f%%', startangle=90)
axes[0, 1].set_title('Holiday')

# Weekday pie chart
weekday_counts = df['weekday'].value_counts()
axes[1, 0].pie(weekday_counts, labels=weekday_counts.index, autopct='%1.1f%%', startangle=90)
axes[1, 0].set_title('Weekday')

# Weather situation pie chart
weather_counts = df['weathersit'].value_counts()
axes[1, 1].pie(weather_counts, labels=weather_counts.index, autopct='%1.1f%%', startangle=90)
axes[1, 1].set_title('Weather Situation')

# Hour of the day pie chart
hour_counts = df['hr'].value_counts()
axes[2, 0].pie(hour_counts, labels=hour_counts.index, autopct='%1.1f%%', startangle=90)
axes[2, 0].set_title('Hour of the Day')

# Remove the empty subplot in the last row
axes[2, 1].axis('off')

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
#Season: Displays the distribution of bike rentals across different seasons.
#Holiday: Shows the proportion of bike rentals on holidays vs. non-holidays.
#Weekday: Indicates bike rental patterns across different days of the week.
#Weather Situation: Reveals how different weather conditions impact bike rentals.
#Hour of the Day: Highlights the hourly variation in bike rentals throughout the day.

# %% [markdown]
# # LINE PLOT

# %%
# Plot 1: Bike Rentals Over Time (by Hour)
plt.figure(figsize=(10, 6))
df.groupby('hr')['cnt'].sum().plot(kind='line', color='blue', marker='o')
plt.title('Bike Rentals by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Bike Rentals')
plt.grid(True)
plt.show()

# %%
#The hourly plot will show patterns in bike rentals throughout the day (e.g., peaks during commute hours).

# %% [markdown]
# # STEM PLOT

# %%
# Plot: Stem plot for Bike Rentals by Hour
plt.figure(figsize=(10, 6))
plt.stem(df.groupby('hr')['cnt'].sum().index, df.groupby('hr')['cnt'].sum(), basefmt=" ")
plt.title('Stem Plot of Bike Rentals by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Bike Rentals')
plt.grid(True)
plt.show()

# Plot: Stem plot for Temperature vs. Bike Rentals
plt.figure(figsize=(10, 6))
plt.stem(df['temp'], df['cnt'], basefmt=" ")
plt.title('Stem Plot of Temperature vs. Bike Rentals')
plt.xlabel('Temperature (Celsius)')
plt.ylabel('Total Bike Rentals')
plt.grid(True)
plt.show()

# %%
#Stem Plot of Bike Rentals by Hour: This will show how bike rentals are distributed by hour of the day.
#Stem Plot of Temperature vs. Bike Rentals: This will show how temperature correlates with bike rentals, displaying each data point.

# %% [markdown]
# #    DATASET-3

# %%
df3 = pd.read_excel('dataset_3.xlsx')

# %%
df3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
df3.shape
# Out:
# (390, 16)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
df3.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
df3.isnull()
# Out:
#      instant  dteday  season     yr   mnth     hr  holiday  weekday  \
# 0      False   False   False  False  False  False    False    False
# 1      False   False   False  False  False  False    False    False
# 2      False   False   False  False  False  False    False    False
# 3      False   False   False  False  False  False    False    False
# 4      False   False   False  False  False  False    False    False
# ..       ...     ...     ...    ...    ...    ...      ...      ...
# 385    False   False   False  False  False  False    False    False
# 386    False   False   False  False  False  False    False    False
# 387    False   False   False  False  False  False    False    False
# 388    False   False   False  False  False  False    False    False
# 389    False   False   False  False  False  False    False    False
#
#      weathersit   temp  atemp    hum  windspeed  casual  registered    cnt
# 0         False  False  False  False      False   False       False  False
# ...

# %%
df3.drop('yr', axis=1, inplace= True)
df3.drop('mnth', axis=1, inplace= True)

# %%
df3
# Out:
#      instant     dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0        620 2011-01-29       1   1    False        6           1  0.22
# 1        621 2011-01-29       1   2    False        6           1  0.22
# 2        622 2011-01-29       1   3    False        6           1  0.20
# 3        623 2011-01-29       1   4    False        6           1  0.16
# 4        624 2011-01-29       1   6    False        6           1  0.16
# ..       ...        ...     ...  ..      ...      ...         ...   ...
# 385      615 2011-01-28       1  20    False        5           2  0.24
# 386      616 2011-01-28       1  21    False        5           2  0.22
# 387      617 2011-01-28       1  22    False        5           1  0.24
# 388      618 2011-01-28       1  23    False        5           1  0.24
# 389      619 2011-01-29       1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
def fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius

df3['temp'] = df3['temp'].apply(fahrenheit_to_celsius)

def fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius

df3['atemp'] = df3['atemp'].apply(fahrenheit_to_celsius)

# %%
df3
# Out:
#      instant     dteday  season  hr  holiday  weekday  weathersit       temp  \
# 0        620 2011-01-29       1   1    False        6           1 -17.655556
# 1        621 2011-01-29       1   2    False        6           1 -17.655556
# 2        622 2011-01-29       1   3    False        6           1 -17.666667
# 3        623 2011-01-29       1   4    False        6           1 -17.688889
# 4        624 2011-01-29       1   6    False        6           1 -17.688889
# ..       ...        ...     ...  ..      ...      ...         ...        ...
# 385      615 2011-01-28       1  20    False        5           2 -17.644444
# 386      616 2011-01-28       1  21    False        5           2 -17.655556
# 387      617 2011-01-28       1  22    False        5           1 -17.644444
# 388      618 2011-01-28       1  23    False        5           1 -17.644444
# 389      619 2011-01-29       1   0    False        6           1 -17.655556
#
# ...

# %%
df3.describe()
# Out:
#            instant                         dteday  season          hr  \
# count   390.000000                            390   390.0  390.000000
# mean    805.500000  2011-02-05 11:45:13.846153728     1.0   11.687179
# min     611.000000            2011-01-28 00:00:00     1.0    0.000000
# 25%     708.250000            2011-02-01 00:00:00     1.0    6.000000
# 50%     805.500000            2011-02-05 12:00:00     1.0   12.000000
# 75%     902.750000            2011-02-10 00:00:00     1.0   18.000000
# max    1000.000000            2011-02-14 00:00:00     1.0   23.000000
# std     112.727548                            NaN     0.0    6.980295
#
#           weekday  weathersit        temp       atemp         hum   windspeed  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     2.989744    1.484615  -17.655556  -17.649765    0.613769    0.179416
# min      0.000000    1.000000  -17.744444  -17.735667    0.210000    0.000000
# ...

# %%
df3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #       VISUALIZATION'S

# %% [markdown]
# #      STEM PLOT

# %%
# Plot 1: Stem plot for Bike Rentals by Hour
plt.figure(figsize=(10, 6))
plt.stem(df3.groupby('hr')['cnt'].sum().index, df3.groupby('hr')['cnt'].sum(), basefmt=" ")
plt.title('Stem Plot of Bike Rentals by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Bike Rentals')
plt.grid(True)
plt.show()

# Plot 2: Stem plot for Temperature vs. Bike Rentals
plt.figure(figsize=(10, 6))
plt.stem(df3['temp'], df3['cnt'], basefmt=" ")
plt.title('Stem Plot of Temperature vs. Bike Rentals')
plt.xlabel('Temperature (Celsius)')
plt.ylabel('Total Bike Rentals')
plt.grid(True)
plt.show()

# %%
#Bike Rentals by Hour: You will observe peak hours when more bikes are rented, likely around morning and evening times.
#Temperature vs. Bike Rentals: You may find that bike rentals are higher during moderate temperatures and lower in extreme cold or hot weather.

# %% [markdown]
# #     HISTOGRAM PLOT

# %%
numerical_columns = ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# Number of columns to display
num_columns = 2
num_rows = (len(numerical_columns) + num_columns - 1) // num_columns  # Calculating number of rows required

# Create a 4-row layout for the histograms
fig, axes = plt.subplots(num_rows, num_columns, figsize=(14, 12))

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop through each column and create histograms
for i, col in enumerate(numerical_columns):
    sns.histplot(df3[col], kde=True, color='skyblue', bins=20, ax=axes[i])  # kde=True adds a kernel density estimate
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

# Adjust layout for better visibility
plt.tight_layout()
plt.show()

# %%
#Skewed Distributions: A skewed distribution may indicate a certain behavior pattern (e.g., a peak in rentals during weekends or holidays).
#Bimodal Distributions: Multiple peaks might indicate different types of users (e.g., casual vs. registered) or external factors (e.g., weather conditions).

# %% [markdown]
# #      SCATTER PLOT

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df3['temp'], df3['cnt'], color='blue', alpha=0.5)
plt.title('Scatter Plot of Temperature vs. Bike Rentals')
plt.xlabel('Temperature (Celsius)')
plt.ylabel('Total Bike Rentals')
plt.grid(True)
plt.show()

# %%
#Temperature vs. Bike Rentals: May reveal a positive correlation, where bike rentals increase with moderate temperatures but decrease in extreme cold or heat.

# %% [markdown]
# #     LINE PLOT

# %%
sns.lineplot(x='dteday', y='cnt', data=df3, marker='o', color='b')

# Set the plot title and labels
plt.title('Line Plot: Count of Rentals Over Time')
plt.xlabel('Date')
plt.ylabel('Count of Rentals')

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
#Line plots reveal trends and relationships over time, such as peak bike rentals during certain hours, temperature's impact on rentals, and the negative effect of humidity and wind speed on bike usage.

# %% [markdown]
# #      BAR PLOT

# %%
# Columns to plot
columns = ['weekday', 'weathersit', 'temp', 'atemp', 'windspeed', 'casual']

# Create a figure with multiple subplots (5 rows, 2 columns)
fig, axes = plt.subplots(3, 2, figsize=(16, 12))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through the columns and create a bar plot for each
for i, column in enumerate(columns):
    # Using seaborn's countplot to show the counts of each unique value in the column
    sns.countplot(x=df3[column], ax=axes[i], palette='Set2')
    axes[i].set_title(f'Bar Plot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Count')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %%
# The bar plots show the distribution of bike rentals across weekdays, weather conditions, temperature ranges, actual temperatures, wind speeds, and the proportion of casual rentals.

# %% [markdown]
# #       PIE CHART

# %%
categorical_columns = ['season', 'holiday', 'weekday', 'weathersit']

# Create a figure with multiple subplots (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through the categorical columns and create a pie chart for each
for i, column in enumerate(categorical_columns):
    # Get the value counts for the column
    value_counts = df3[column].value_counts()
    
    # Plot the pie chart
    axes[i].pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', colors=sns.color_palette("Set2", len(value_counts)))
    
    # Set title for each pie chart
    axes[i].set_title(f'Pie Chart for {column}')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# #         CONCATENATE

# %%
df4 = pd.concat([df, df3], axis=0, join='outer', ignore_index=True)

# %%
df4
# Out:
#      instant     dteday  season   yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1  0.0   1.0   0    False        6           1
# 1          2 2011-01-01       1  0.0   1.0   1    False        6           1
# 2          3 2011-01-01       1  0.0   1.0   2    False        6           1
# 3          4 2011-01-01       1  0.0   1.0   3    False        6           1
# 4          5 2011-01-01       1  0.0   1.0   4    False        6           1
# ..       ...        ...     ...  ...   ...  ..      ...      ...         ...
# 995      615 2011-01-28       1  NaN   NaN  20    False        5           2
# 996      616 2011-01-28       1  NaN   NaN  21    False        5           2
# 997      617 2011-01-28       1  NaN   NaN  22    False        5           1
# 998      618 2011-01-28       1  NaN   NaN  23    False        5           1
# 999      619 2011-01-29       1  NaN   NaN   0    False        6           1
#
# ...

# %%
df4.drop('yr', axis=1, inplace= True)
df4.drop('mnth', axis=1, inplace= True)

# %%
df4
# Out:
#      instant     dteday  season  hr  holiday  weekday  weathersit       temp  \
# 0          1 2011-01-01       1   0    False        6           1   0.240000
# 1          2 2011-01-01       1   1    False        6           1   0.220000
# 2          3 2011-01-01       1   2    False        6           1   0.220000
# 3          4 2011-01-01       1   3    False        6           1   0.240000
# 4          5 2011-01-01       1   4    False        6           1   0.240000
# ..       ...        ...     ...  ..      ...      ...         ...        ...
# 995      615 2011-01-28       1  20    False        5           2 -17.644444
# 996      616 2011-01-28       1  21    False        5           2 -17.655556
# 997      617 2011-01-28       1  22    False        5           1 -17.644444
# 998      618 2011-01-28       1  23    False        5           1 -17.644444
# 999      619 2011-01-29       1   0    False        6           1 -17.655556
#
# ...

# %%
df4.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df4.drop_duplicates()
# Out:
#      instant     dteday  season  hr  holiday  weekday  weathersit       temp  \
# 0          1 2011-01-01       1   0    False        6           1   0.240000
# 1          2 2011-01-01       1   1    False        6           1   0.220000
# 2          3 2011-01-01       1   2    False        6           1   0.220000
# 3          4 2011-01-01       1   3    False        6           1   0.240000
# 4          5 2011-01-01       1   4    False        6           1   0.240000
# ..       ...        ...     ...  ..      ...      ...         ...        ...
# 995      615 2011-01-28       1  20    False        5           2 -17.644444
# 996      616 2011-01-28       1  21    False        5           2 -17.655556
# 997      617 2011-01-28       1  22    False        5           1 -17.644444
# 998      618 2011-01-28       1  23    False        5           1 -17.644444
# 999      619 2011-01-29       1   0    False        6           1 -17.655556
#
# ...

# %% [markdown]
# # VISUALIZATION's

# %% [markdown]
# # LINE PLOT

# %%
# List of numerical columns you want to plot
numerical_columns = ['temp', 'atemp', 'hum', 'windspeed']

# Create subplots for each numerical column
plt.figure(figsize=(14, 12))

for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)  # 2 rows, 2 columns
    sns.lineplot(x=df4['dteday'], y=df4[column])
    plt.title(f'{column} Over Time')
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.xticks(rotation=45)
    
plt.tight_layout()
plt.show()

# %%
# The line plots reveal trends and fluctuations over time for each feature, highlighting patterns, seasonality, and potential anomalies in the data.

# %% [markdown]
# #  VIOLIN PLOT

# %%
# List of numerical columns
numerical_columns = ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# Create a figure with subplots for each numerical column
plt.figure(figsize=(16, 12))

# Plot violin plots for each numerical column with respect to the 'season' column
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)  # Adjust the number of rows and columns as necessary
    sns.violinplot(data=df4, x='season', y=column, palette='Set2')
    plt.title(f'Violin Plot for {column} by Season')
    plt.xlabel('Season')
    plt.ylabel(column)

plt.tight_layout()
plt.show()

# %%
#The width of the "violin" at different values shows the density, so a wider region indicates more data points in that range.
#It combines aspects of both a box plot (for the summary statistics) and a density plot (for the distribution of data).

# %% [markdown]
# # HISTOGRAM PLOT

# %%
# List of numerical columns
numerical_columns = df4.select_dtypes(include=['float64', 'int64']).columns

# Calculate the number of rows and columns required
num_plots = len(numerical_columns)
num_columns = 3  
num_rows = np.ceil(num_plots / num_columns).astype(int)

# Set up the figure for multiple plots
plt.figure(figsize=(15, num_rows * 5))

# Iterate over the columns and create a histogram for each
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(num_rows, num_columns, i)  # Adjust number of rows and columns dynamically
    sns.histplot(df4[column], bins=20, kde=True, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

# Adjust layout to avoid overlap and display the plot
plt.tight_layout()
plt.show()

# %%
# The histograms show the distribution of each numerical feature, revealing patterns such as skewness, central tendency, and variability in the data

# %% [markdown]
# # CORRELATION's

# %% [markdown]
# # HEATMAP

# %%
correlation_matrix = df4.corr()
print("Correlation Matrix:\n", correlation_matrix)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Correlation Matrix:
#               instant    dteday  season        hr   holiday   weekday  \
# instant     1.000000  0.999540     NaN  0.000060 -0.063013  0.008157
# dteday      0.999540  1.000000     NaN -0.022421 -0.068456  0.010248
# season           NaN       NaN     NaN       NaN       NaN       NaN
# hr          0.000060 -0.022421     NaN  1.000000 -0.005753  0.007531
# holiday    -0.063013 -0.068456     NaN -0.005753  1.000000 -0.148682
# weekday     0.008157  0.010248     NaN  0.007531 -0.148682  1.000000
# weathersit  0.030439  0.033310     NaN -0.055802  0.165443  0.060007
# temp       -0.845757 -0.853001     NaN  0.009077  0.125003 -0.003275
# atemp       0.077546  0.078681     NaN  0.148524 -0.072091 -0.051646
# hum         0.062116  0.073485     NaN -0.194853 -0.037542  0.062469
# windspeed  -0.057837 -0.064148     NaN  0.116640 -0.001111 -0.056754
# casual      0.071259  0.065002     NaN  0.204476 -0.000944 -0.047363
# ...

# %%
#The heatmap reveals the correlations between variables, showing strong relationships between temperature-related features and bike rentals, while weather conditions and humidity have weaker correlations.

# %% [markdown]
# #   BOX PLOT TO FIND OULIERS IN FINAL DATA

# %%
# Set the number of rows and columns for the plot
num_columns = df4.select_dtypes(include=['float64', 'int64']).columns  # Selecting numerical columns
num_plots = len(num_columns)

# Set up the number of rows and columns for the subplots
num_rows = (num_plots // 3) + (num_plots % 3 > 0)  # Assuming you want 3 columns per row

# Create a figure with subplots
fig, axes = plt.subplots(num_rows, 3, figsize=(18, num_rows * 5))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Loop over the numerical columns and create a box plot for each
for i, col in enumerate(num_columns):
    sns.boxplot(data=df4, x=col, ax=axes[i])
    axes[i].set_title(f'Box Plot for {col}')
    axes[i].set_xlabel(col)

# Hide empty subplots if any
for i in range(num_plots, len(axes)):
    axes[i].axis('off')

# Adjust layout for better visibility
plt.tight_layout()
plt.show()

# %%
# Here we can see that by using box plot we can easily identify the outliers.
# outliers are present in (weathersit , temp , atemp , windspeed , casual , registered , cnt)

# %% [markdown]
# #  Z-scores Method:

# %%
import pandas as pd

# Assuming df4 is your dataset
numerical_columns = df4.select_dtypes(include=['float64', 'int64']).columns

# Create a mask to filter out the rows that contain outliers
for column in numerical_columns:
    Q1 = df4[column].quantile(0.25)
    Q3 = df4[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Define the conditions for valid data (within the IQR range)
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter out outliers
    df4 = df4[(df4[column] >= lower_bound) & (df4[column] <= upper_bound)]

# Now df4 will have the outliers removed
print(df4.head(10))
# Out:
#    instant     dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0        1 2011-01-01       1   0    False        6           1  0.24
# 1        2 2011-01-01       1   1    False        6           1  0.22
# 2        3 2011-01-01       1   2    False        6           1  0.22
# 3        4 2011-01-01       1   3    False        6           1  0.24
# 4        5 2011-01-01       1   4    False        6           1  0.24
# 5        6 2011-01-01       1   5    False        6           2  0.24
# 6        7 2011-01-01       1   6    False        6           1  0.22
# 7        8 2011-01-01       1   7    False        6           1  0.20
# 8        9 2011-01-01       1   8    False        6           1  0.24
# 9       10 2011-01-01       1   9    False        6           1  0.32
#
#        atemp   hum  windspeed  casual  registered  cnt
# 0 -17.617833  0.81     0.0000       3          13   16
# 1 -17.626278  0.80     0.0000       8          32   40
# ...

# %%
# Assuming df4 is your DataFrame and it contains numerical columns
numerical_columns = df4.select_dtypes(include=['float64', 'int64']).columns

# Define a threshold for identifying outliers using IQR (Interquartile Range)
threshold = 1.5  # The default for IQR is 1.5

# Iterate through each numerical column
for column in numerical_columns:
    # Calculate the first (Q1) and third (Q3) quartiles
    Q1 = df4[column].quantile(0.25)
    Q3 = df4[column].quantile(0.75)
    
    # Calculate IQR
    IQR = Q3 - Q1
    
    # Define the bounds for detecting outliers
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR
    
    # Find outliers (values outside the bounds)
    outliers = (df4[column] < lower_bound) | (df4[column] > upper_bound)
    
    # Replace outliers with the median
    median = df4[column].median()
    df4[column] = df4[column].where(~outliers, median)

# Check the first few rows of the updated DataFrame
print(df4.head())
# Out:
#    instant     dteday  season  hr  holiday  weekday  weathersit  temp  \
# 0        1 2011-01-01       1   0    False        6           1  0.24
# 1        2 2011-01-01       1   1    False        6           1  0.22
# 2        3 2011-01-01       1   2    False        6           1  0.22
# 3        4 2011-01-01       1   3    False        6           1  0.24
# 4        5 2011-01-01       1   4    False        6           1  0.24
#
#        atemp   hum  windspeed  casual  registered  cnt
# 0 -17.617833  0.81        0.0       3          13   16
# 1 -17.626278  0.80        0.0       8          32   40
# 2 -17.626278  0.80        0.0       5          27   32
# 3 -17.617833  0.75        0.0       3          10   13
# 4 -17.617833  0.75        0.0       0           1    1

# %% [markdown]
# #  Box plot after removing outliers

# %%
# Assuming df4 is your DataFrame and it contains numerical columns
numerical_columns = df4.select_dtypes(include=['float64', 'int64']).columns

# Calculate the number of subplots needed
n_columns = len(numerical_columns)
n_rows = (n_columns // 3) + (n_columns % 3 != 0)

# Create box plots for each numerical column
plt.figure(figsize=(15, 5 * n_rows))

# Create box plots for each numerical column
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(n_rows, 3, i)  # Adjusting based on the number of columns
    sns.boxplot(data=df4, x=column)
    plt.title(f'Box plot for {column}')
    plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# # Code to save file as csv

# %%
df4.to_csv('Project-2 cleaned dataset.csv', index=False)
